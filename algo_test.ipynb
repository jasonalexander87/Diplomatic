# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
os.chdir("/content/drive/MyDrive/Diplomatic1/Implementation/algo_test")
# !ls
# Out:
#  algo_test.ipynb		       dataset_Final_FS_COR_3.csv
# 'Copy of dataset_Final_FS_COR_3.csv'   final_model.sav

# %%
#SCRIPT7 K-FOLD CROSS VALIDATION
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn import metrics
from sklearn import svm
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB

#url = 'dataset_Final_FS_DT_1.csv'
url = 'dataset_Final_FS_COR_3.csv'
#url = 'https://raw.githubusercontent.com/jasonalexander87/machineL/main/dataset_Final_FS_DT_1.csv'
#url = 'https://raw.githubusercontent.com/jasonalexander87/machineL/main/dataset_Final_FS_COR_2.csv'

df = pd.read_csv(url)

Y = df.CATEGORY
del df['CATEGORY']
X = df
iterations = 100
accuracy_avg = 0
recall_avg = [0,0,0,0,0]
precission_avg = [0,0,0,0,0]

for i in range(1):

  X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.3)
  clf_dt = RandomForestClassifier()
  #clf_dt = MLPClassifier()
  #clf_dt = KNeighborsClassifier()
  #clf_dt =  GaussianNB()


  clf_dt.fit(X_train,y_train)

  labels = clf_dt.classes_
  #print(labels)
  #print('======')

  y_pred_dt=clf_dt.predict(X_test)

  accuracy = metrics.accuracy_score(y_test, y_pred_dt)
  recall = metrics.recall_score(y_test, y_pred_dt,average=None)
  precision = metrics.precision_score(y_test, y_pred_dt,average=None)


print("Accuracy for RF:",accuracy)
print("Precision for RF:",precision)
print("Recall for RF:",recall)
# Out:
# Accuracy for RF: 0.8827639751552795
# Precision for RF: [0.96865204 0.93726937 0.79197995 0.87407407 0.75862069]
# Recall for RF: [0.94785276 0.84949833 0.96048632 0.76375405 0.88      ]
